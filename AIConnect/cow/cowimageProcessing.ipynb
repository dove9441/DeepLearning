# %%
import os
import pandas as pd
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt


imgs = []
trainY = []
filelist = os.listdir('/workspace/AIConnect/cow/train/images/')
print('1123123')
for i in filelist[:50]:
    # 사진 추가s
    img = Image.open('/workspace/AIConnect/cow//train/images/'+i).crop((30,52, 172,194)).resize((142,142))
    imgs.append(img)
print('asdasd')
plt.imshow(imgs[18])
plt.show()
# Out:
# 1123123
# asdasd
